# %%
from bs4 import BeautifulSoup
from bs4.element import Comment
import re
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')
import html5lib
import glob
import codecs
import os
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mateomontoya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
print ("The current working directory is", os.getcwd())
# Out:
# The current working directory is /Users/mateomontoya/Desktop/bovary_work_summer2019

# %% [markdown]
# Parsing one HTML file first as a test

# %%
DATA_DIR = 'folios_copy'
fname = '1.html'
fname = os.path.join(DATA_DIR, fname)
#with open(fname) as f:
with codecs.open(fname, "r", encoding='utf-8', errors='ignore') as f: ##for special encoding issues  
    soup = BeautifulSoup(f, "html")
    
    
##to test uncomment below
soup
# Out:
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="http://www.bovary.fr/style_bovary/public.css" rel="stylesheet" type="text/css"/>
# </head>
# <body class="body_blanc"><div id="M">
# <table align="center" border="0" cellpadding="5" cellspacing="0" width="100%"><tr><td> <hors-corpus> I, chap. 9 : Départ de Tostes - brouillons, vol. 2, folio 2v<br/>
# <br/>
# </hors-corpus>
# <table cellspacing="0" width="100%">
# <tr><td align="right" width="30%">
#
#   </td><td width="70%">
# </td></tr>
# <tr><td align="center">
#
#   </td><td align="center">
#        143
#   </td></tr>
# <tr><td align="center">
#
#   </td><td>
# <s>Quand le froid de la nuit commençait à  la saisir</s><br/>
# <i>                                      <s>alors</s></i><br/>
#         elle   se   déshabillait   <s>alors</s>,   <s>et ayant de nouveau rangé</s><br/>
# <i>                                                                           le</i><br/>
#                       <i>petites  étant rangées                      <s>son</s></i>
# </td></tr>
# <tr><td align="right">
# <i>et</i>
# </td><td>
#        toutes ses affaires se glissait doucement dans <s>le</s> lit à  côté de<br/>
#       Charles qui dormait.<br/>
# <i>                                                        <s> tout à  coup</s></i><br/>
#                              <i>à                    par crises   elle</i><br/>
# <i><s>longtemps</s></i><br/>
#                             <s>en</s> certains jours, <s>elle se mettait à  </s> bavard<s>er</s>/ait
#   </td></tr>
# <tr><td align="right">
# <i>tout à  coup</i>
# </td><td>
# <i>                                     ement<br/>
#                    un entraînement<br/>
# </i>avec une <s>volubilité</s> fébrile, <s>contant des histoires</s>,
#   </td></tr>
# <tr><td align="right">
# <i><s>animée</s></i>
# </td><td>
# <s>fais<u>ant</u> des projets, s'adres<u>sant</u> à  tout, riant très<br/>
#       haut, criant fort</s> / <s>faisant des exclamations</s>, <s>animée</s><br/>
# <s>exhaltée</s>, et à  ces <s>exhalt</s>  exaltations succédaient des<br/>
# <i>                                                                     ni</i><br/>
#       torpeurs <s>profondes</s> où elle restait sans parler sans bouger<br/>
# <i>                  <s> inerte, la tête</s>        comme  </i><br/>
# <s>la tête sur la poitrine</s>, inerte et n'entendant <s>plus<br/>
# </s>       <i> <s>alors<br/>
# </s>      <s>alors</s>       la ranimait un peu  <s>alors</s></i><br/>
#       rien. - Ce qui lui faisait du bien c'était de se verser <br/>
# <i>                             <s>de</s></i><br/>
#                  <i><s>poitrine</s> une bouteille entière</i><br/>
# <s>alors</s> sur la tête <s>un flacon</s> <s>entier/e</s> d'eau de cologne.<br/>
# <i>                      <s>car</s> <s>e</s>t</i><br/>
# <s>cela la ranimait</s>. elle se fatiguait ainsi les <br/>
# <i>                                             <s>et</s> porta<s>i</s>/ant <s>même</s></i><br/>
#       nerfs par l'abus des senteurs, <s>et portait<br/>
# </s>    <i>d'ordinaire</i><br/>
#       habituellement dans la poche de son tablier un flacon<br/>
#       de sel anglais qu'elle respirait à  toute minute.<br/>
#        <i>                          <s>sans cesse</s>                          <s> sans cesse</s></i>
# </td></tr>
# <tr><td align="center">
# <i>continuellement<br/>
#       et</i>
# </td><td>
#                        Comme elle se plaignait de Tostes <s>continuellement</s><br/>
#       à  tout propos ( s'en prenant au pays lui-même du malheur<br/>
#                                                                      <i>rêver</i><br/>
#       d'y vivre) Charles qui se tourmentait à  réfléchir sur<br/>
#           <i>sans y rien comprendre<br/>
#                                          <s>tout seul</s>*                <s>en effet</s></i><br/>
#       sa   maladie   s'imagina   qu'elle pourrait bien avoir<br/>
# <i>                                                          <s>enfin</s>          <s>à  </s></i><br/>
# <i>           <s>inconnue</s>                       A     et s'arrêtant à  cette idée</i>
# </td></tr>
# <tr><td align="center">
# <i>B <s>qu'il ne connaissait<br/>
#       pas</s><br/>
#       que <s>peut-être</s> l'air de tostes</i>
# </td><td>
#        sa cause dans qqu'  influence locale X que <s>l'air  du pays<br/>
# </s>           <i><s>secrète</s> </i><br/>
#                 <i><s>l'air de la contrée</s> <s>pr elle</s></i><br/>
#       peut-être  <u>était   trop  vif</u>      <s>et s'arrêtant à  cette idée</s><br/>
# <i>songea sérieusement              afin de lui remettre</i><br/>
# <s>pensa</s> à  aller s'établir ailleurs pr lui rétablir<br/>
# <s>s</s>/la santé.
#   </td></tr>
# <tr><td align="right" width="30%">
#
#   </td><td width="70%">
# </td></tr>
# </table>
# <hors-corpus> [Transcription de Michèle Lemal]<br/>
# <br/>
# </hors-corpus></td></tr></table>
# </div></body></html>

# %% [markdown]
# Taking only the first 20 files because all the files take several minutes

# %%
DATA_DIR = 'folios_copy'
fnames = os.path.join(DATA_DIR, '*.html')[:20]
fnames = glob.glob(fnames)
folios_raw = []
folios_soup = []
#with open(fname) as f:
for fname in fnames:
    with codecs.open(fname, "r", encoding='utf-8', errors='ignore') as f: ##for special encoding issues
        soup = BeautifulSoup(f, "html")
    folios_soup.append(soup)

# %%
##To test uncomment below
#folios_soup[1]

# %%
folios_text = []

for soupy in folios_soup:
    texts = soup.findAll(text=True)
    folios_text.append(texts)

# %%
folios_text[:5]
# Out:
# [['\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   ' ',
#   ' I, chap.7 : Madame Bovary mère à Tostes - définitif, vol.1, folio 87 ',
#   '\n',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n       87 \n  ',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0',
#   'avidement',
#   '\n',
#   'de sa journée',
#   ', il mangeait ',
#   'avec appétit',
#   ' le reste du miroton',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0',
#   'en souriant',
#   '\n',
#   'épluchait son fromage ',
#   '/ en souriant',
#   ' , croquait une pomme',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'puis',
#   '\n',
#   'vidait la caraffe, ',
#   'après',
#   ' ',
#   'quoi il',
#   " s'allait ",
#   'se',
#   ' mettre au lit, ',
#   'sentant',
#   "\n      [le cidre éventé qu'il avait bu]",
#   ', se couchait sur le dos et',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 [',
#   'illis.]',
#   '\n      ronflait.',
#   'comme un mort',
#   '*',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 [',
#   'illis.]',
#   '\n',
#   "\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0Comme il avait eu longtemps l'habitude du bonnet",
#   '\n      de coton, son foulard ',
#   'mal mis',
#   ' ne lui tenait pas aux oreilles',
#   '\n      aussi ses cheveux le matin étaient',
#   '-ils',
#   ' rabattus pêle-mêle',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'sali',
#   's* par le',
#   '\n      sur sa figure, et ',
#   'plein du',
#   ' duvet de son oreiller, dont',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'blanchis',
#   '\n      les cordons ',
#   'de la coiffe',
#   ' se dénouaient pendant la nuit',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 toujours',
#   '\n      Il portait ',
#   'toujours',
#   ' de fortes bottes et qui avaient',
#   '\n      au coup de pied, deux plis épais obliquant vers les chevilles,',
#   "\n      tandis que le reste de l'empeigne ",
#   'dont rien ne ridait',
#   '\n      le cuir dur',
#   ', se continuait en ligne droite, tendu comme',
#   "\n      par un pied de bois. Il disait que «\xa0c'était bon assez bon",
#   '\n      pr la campagne.\xa0»',
#   "\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Sa mère l'approuvait ",
#   "d'ailleurs",
#   ' en cette',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   '\xa0voir',
#   "\n      économie. Car elle le venait, comme autrefois, lorsqu'il",
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 chez elle',
#   '\n      y avait eu ',
#   'dans son ménage',
#   ' quelque bourrasque un',
#   '\n      \xa0peu violente.\xa0 \n  ',
#   '\n',
#   '\n',
#   'et prtant Me Bovary mère semblait prévenue',
#   '\n      contre sa bru elle',
#   '\n      lui trouvait',
#   '\n      \xa0',
#   'un genre trop relevé',
#   '\n',
#   ' \xa0pr leur position de fortune',
#   '\n      \xa0le bois & le sucre et',
#   '\n      \xa0la chandelle ',
#   'filaient',
#   '\n      comme dans une',
#   '\n      grande maison',
#   ' &',
#   '\n      la quantité de braise',
#   '\n      qui se brûlait à',
#   '\n      la cuisine aurait',
#   '\n      suffi pr vingt-cinq',
#   '\n      \xa0plats',
#   '\n',
#   '\n       {{',
#   'si jadis elle avait été aveuglée sur le',
#   '\n      compte de la veuve Dubuc, en revanche',
#   ' elle semblait',
#   '\n',
#   'maintenant',
#   ' prévenue ',
#   'sans motif',
#   ' contre Mlle',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Mr son époux',
#   '\n      Rouault tandis que ',
#   'son mari',
#   ' la déclarait, au contraire',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'déclarait',
#   '\n',
#   '\xa0une personne charmante. ',
#   'il disait que son fils avait',
#   '\n',
#   'Leur',
#   '\n',
#   'son fils avait bien fait de la prendre',
#   '\n',
#   "bien fait de la prendre. S'il avait été dupé une première",
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'si son fils une première fois avait été dupé',
#   '\n',
#   'fois - à qui la faute\xa0? ',
#   'est-ce que',
#   " les femmes d'ailleurs",
#   '\n',
#   'ne',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'rien',
#   "\n      s'entendaient à ",
#   'quelque chose . on était bien malheureux',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'pouvaient',
#   "\n      d'en ",
#   'avoir',
#   ' une. ',
#   'les pays où les ',
#   'maris',
#   ' ',
#   ' ',
#   'pouvaient',
#   '\n      les tuer ',
#   'impunément,',
#   ' ',
#   'étaient les mieux gouvernés et enfin',
#   '\n',
#   'toujours',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   ' en finissant ',
#   " de n'avoir",
#   '\n',
#   ' ',
#   "d'habitude",
#   ' ',
#   '& il se lamentait ',
#   'en finissant sur ce',
#   '\n',
#   '\xa0',
#   "qu'il n'avait ",
#   ' ',
#   "pas profité de sa jeunesse pr s'amuser",
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'suffisamment',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'suffisamment',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0',
#   'suffisamment',
#   '}} \n  ',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\n',
#   '\n',
#   ' [Transcription de Françoise Robin] ',
#   '\n'],
#  ['\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   ' ',
#   ' I, chap.7 : Madame Bovary mère à Tostes - définitif, vol.1, folio 87 ',
#   '\n',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n       87 \n  ',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0',
#   'avidement',
#   '\n',
#   'de sa journée',
#   ', il mangeait ',
#   'avec appétit',
#   ' le reste du miroton',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0',
#   'en souriant',
#   '\n',
#   'épluchait son fromage ',
#   '/ en souriant',
#   ' , croquait une pomme',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'puis',
#   '\n',
#   'vidait la caraffe, ',
#   'après',
#   ' ',
#   'quoi il',
#   " s'allait ",
#   'se',
#   ' mettre au lit, ',
#   'sentant',
#   "\n      [le cidre éventé qu'il avait bu]",
#   ', se couchait sur le dos et',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 [',
#   'illis.]',
#   '\n      ronflait.',
#   'comme un mort',
#   '*',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 [',
#   'illis.]',
#   '\n',
#   "\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0Comme il avait eu longtemps l'habitude du bonnet",
#   '\n      de coton, son foulard ',
#   'mal mis',
#   ' ne lui tenait pas aux oreilles',
#   '\n      aussi ses cheveux le matin étaient',
#   '-ils',
#   ' rabattus pêle-mêle',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'sali',
#   's* par le',
#   '\n      sur sa figure, et ',
#   'plein du',
#   ' duvet de son oreiller, dont',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'blanchis',
#   '\n      les cordons ',
#   'de la coiffe',
#   ' se dénouaient pendant la nuit',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 toujours',
#   '\n      Il portait ',
#   'toujours',
#   ' de fortes bottes et qui avaient',
#   '\n      au coup de pied, deux plis épais obliquant vers les chevilles,',
#   "\n      tandis que le reste de l'empeigne ",
#   'dont rien ne ridait',
#   '\n      le cuir dur',
#   ', se continuait en ligne droite, tendu comme',
#   "\n      par un pied de bois. Il disait que «\xa0c'était bon assez bon",
#   '\n      pr la campagne.\xa0»',
#   "\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Sa mère l'approuvait ",
#   "d'ailleurs",
#   ' en cette',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   '\xa0voir',
#   "\n      économie. Car elle le venait, comme autrefois, lorsqu'il",
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 chez elle',
#   '\n      y avait eu ',
#   'dans son ménage',
#   ' quelque bourrasque un',
#   '\n      \xa0peu violente.\xa0 \n  ',
#   '\n',
#   '\n',
#   'et prtant Me Bovary mère semblait prévenue',
#   '\n      contre sa bru elle',
#   '\n      lui trouvait',
#   '\n      \xa0',
#   'un genre trop relevé',
#   '\n',
#   ' \xa0pr leur position de fortune',
#   '\n      \xa0le bois & le sucre et',
#   '\n      \xa0la chandelle ',
#   'filaient',
#   '\n      comme dans une',
#   '\n      grande maison',
#   ' &',
#   '\n      la quantité de braise',
#   '\n      qui se brûlait à',
#   '\n      la cuisine aurait',
#   '\n      suffi pr vingt-cinq',
#   '\n      \xa0plats',
#   '\n',
#   '\n       {{',
#   'si jadis elle avait été aveuglée sur le',
#   '\n      compte de la veuve Dubuc, en revanche',
#   ' elle semblait',
#   '\n',
#   'maintenant',
#   ' prévenue ',
#   'sans motif',
#   ' contre Mlle',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Mr son époux',
#   '\n      Rouault tandis que ',
#   'son mari',
#   ' la déclarait, au contraire',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'déclarait',
#   '\n',
#   '\xa0une personne charmante. ',
#   'il disait que son fils avait',
#   '\n',
#   'Leur',
#   '\n',
#   'son fils avait bien fait de la prendre',
#   '\n',
#   "bien fait de la prendre. S'il avait été dupé une première",
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'si son fils une première fois avait été dupé',
#   '\n',
#   'fois - à qui la faute\xa0? ',
#   'est-ce que',
#   " les femmes d'ailleurs",
#   '\n',
#   'ne',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'rien',
#   "\n      s'entendaient à ",
#   'quelque chose . on était bien malheureux',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'pouvaient',
#   "\n      d'en ",
#   'avoir',
#   ' une. ',
#   'les pays où les ',
#   'maris',
#   ' ',
#   ' ',
#   'pouvaient',
#   '\n      les tuer ',
#   'impunément,',
#   ' ',
#   'étaient les mieux gouvernés et enfin',
#   '\n',
#   'toujours',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   ' en finissant ',
#   " de n'avoir",
#   '\n',
#   ' ',
#   "d'habitude",
#   ' ',
#   '& il se lamentait ',
#   'en finissant sur ce',
#   '\n',
#   '\xa0',
#   "qu'il n'avait ",
#   ' ',
#   "pas profité de sa jeunesse pr s'amuser",
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'suffisamment',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'suffisamment',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0',
#   'suffisamment',
#   '}} \n  ',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\n',
#   '\n',
#   ' [Transcription de Françoise Robin] ',
#   '\n'],
#  ['\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   ' ',
#   ' I, chap.7 : Madame Bovary mère à Tostes - définitif, vol.1, folio 87 ',
#   '\n',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n       87 \n  ',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0',
#   'avidement',
#   '\n',
#   'de sa journée',
#   ', il mangeait ',
#   'avec appétit',
#   ' le reste du miroton',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0',
#   'en souriant',
#   '\n',
#   'épluchait son fromage ',
#   '/ en souriant',
#   ' , croquait une pomme',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'puis',
#   '\n',
#   'vidait la caraffe, ',
#   'après',
#   ' ',
#   'quoi il',
#   " s'allait ",
#   'se',
#   ' mettre au lit, ',
#   'sentant',
#   "\n      [le cidre éventé qu'il avait bu]",
#   ', se couchait sur le dos et',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 [',
#   'illis.]',
#   '\n      ronflait.',
#   'comme un mort',
#   '*',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 [',
#   'illis.]',
#   '\n',
#   "\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0Comme il avait eu longtemps l'habitude du bonnet",
#   '\n      de coton, son foulard ',
#   'mal mis',
#   ' ne lui tenait pas aux oreilles',
#   '\n      aussi ses cheveux le matin étaient',
#   '-ils',
#   ' rabattus pêle-mêle',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'sali',
#   's* par le',
#   '\n      sur sa figure, et ',
#   'plein du',
#   ' duvet de son oreiller, dont',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'blanchis',
#   '\n      les cordons ',
#   'de la coiffe',
#   ' se dénouaient pendant la nuit',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 toujours',
#   '\n      Il portait ',
#   'toujours',
#   ' de fortes bottes et qui avaient',
#   '\n      au coup de pied, deux plis épais obliquant vers les chevilles,',
#   "\n      tandis que le reste de l'empeigne ",
#   'dont rien ne ridait',
#   '\n      le cuir dur',
#   ', se continuait en ligne droite, tendu comme',
#   "\n      par un pied de bois. Il disait que «\xa0c'était bon assez bon",
#   '\n      pr la campagne.\xa0»',
#   "\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Sa mère l'approuvait ",
#   "d'ailleurs",
#   ' en cette',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   '\xa0voir',
#   "\n      économie. Car elle le venait, comme autrefois, lorsqu'il",
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 chez elle',
#   '\n      y avait eu ',
#   'dans son ménage',
#   ' quelque bourrasque un',
#   '\n      \xa0peu violente.\xa0 \n  ',
#   '\n',
#   '\n',
#   'et prtant Me Bovary mère semblait prévenue',
#   '\n      contre sa bru elle',
#   '\n      lui trouvait',
#   '\n      \xa0',
#   'un genre trop relevé',
#   '\n',
#   ' \xa0pr leur position de fortune',
#   '\n      \xa0le bois & le sucre et',
#   '\n      \xa0la chandelle ',
#   'filaient',
#   '\n      comme dans une',
#   '\n      grande maison',
#   ' &',
#   '\n      la quantité de braise',
#   '\n      qui se brûlait à',
#   '\n      la cuisine aurait',
#   '\n      suffi pr vingt-cinq',
#   '\n      \xa0plats',
#   '\n',
#   '\n       {{',
#   'si jadis elle avait été aveuglée sur le',
#   '\n      compte de la veuve Dubuc, en revanche',
#   ' elle semblait',
#   '\n',
#   'maintenant',
#   ' prévenue ',
#   'sans motif',
#   ' contre Mlle',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Mr son époux',
#   '\n      Rouault tandis que ',
#   'son mari',
#   ' la déclarait, au contraire',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'déclarait',
#   '\n',
#   '\xa0une personne charmante. ',
#   'il disait que son fils avait',
#   '\n',
#   'Leur',
#   '\n',
#   'son fils avait bien fait de la prendre',
#   '\n',
#   "bien fait de la prendre. S'il avait été dupé une première",
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'si son fils une première fois avait été dupé',
#   '\n',
#   'fois - à qui la faute\xa0? ',
#   'est-ce que',
#   " les femmes d'ailleurs",
#   '\n',
#   'ne',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'rien',
#   "\n      s'entendaient à ",
#   'quelque chose . on était bien malheureux',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'pouvaient',
#   "\n      d'en ",
#   'avoir',
#   ' une. ',
#   'les pays où les ',
#   'maris',
#   ' ',
#   ' ',
#   'pouvaient',
#   '\n      les tuer ',
#   'impunément,',
#   ' ',
#   'étaient les mieux gouvernés et enfin',
#   '\n',
#   'toujours',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   ' en finissant ',
#   " de n'avoir",
#   '\n',
#   ' ',
#   "d'habitude",
#   ' ',
#   '& il se lamentait ',
#   'en finissant sur ce',
#   '\n',
#   '\xa0',
#   "qu'il n'avait ",
#   ' ',
#   "pas profité de sa jeunesse pr s'amuser",
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'suffisamment',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'suffisamment',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0',
#   'suffisamment',
#   '}} \n  ',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\n',
#   '\n',
#   ' [Transcription de Françoise Robin] ',
#   '\n'],
#  ['\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   ' ',
#   ' I, chap.7 : Madame Bovary mère à Tostes - définitif, vol.1, folio 87 ',
#   '\n',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n       87 \n  ',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0',
#   'avidement',
#   '\n',
#   'de sa journée',
#   ', il mangeait ',
#   'avec appétit',
#   ' le reste du miroton',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0',
#   'en souriant',
#   '\n',
#   'épluchait son fromage ',
#   '/ en souriant',
#   ' , croquait une pomme',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'puis',
#   '\n',
#   'vidait la caraffe, ',
#   'après',
#   ' ',
#   'quoi il',
#   " s'allait ",
#   'se',
#   ' mettre au lit, ',
#   'sentant',
#   "\n      [le cidre éventé qu'il avait bu]",
#   ', se couchait sur le dos et',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 [',
#   'illis.]',
#   '\n      ronflait.',
#   'comme un mort',
#   '*',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 [',
#   'illis.]',
#   '\n',
#   "\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0Comme il avait eu longtemps l'habitude du bonnet",
#   '\n      de coton, son foulard ',
#   'mal mis',
#   ' ne lui tenait pas aux oreilles',
#   '\n      aussi ses cheveux le matin étaient',
#   '-ils',
#   ' rabattus pêle-mêle',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'sali',
#   's* par le',
#   '\n      sur sa figure, et ',
#   'plein du',
#   ' duvet de son oreiller, dont',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'blanchis',
#   '\n      les cordons ',
#   'de la coiffe',
#   ' se dénouaient pendant la nuit',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 toujours',
#   '\n      Il portait ',
#   'toujours',
#   ' de fortes bottes et qui avaient',
#   '\n      au coup de pied, deux plis épais obliquant vers les chevilles,',
#   "\n      tandis que le reste de l'empeigne ",
#   'dont rien ne ridait',
#   '\n      le cuir dur',
#   ', se continuait en ligne droite, tendu comme',
#   "\n      par un pied de bois. Il disait que «\xa0c'était bon assez bon",
#   '\n      pr la campagne.\xa0»',
#   "\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Sa mère l'approuvait ",
#   "d'ailleurs",
#   ' en cette',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   '\xa0voir',
#   "\n      économie. Car elle le venait, comme autrefois, lorsqu'il",
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 chez elle',
#   '\n      y avait eu ',
#   'dans son ménage',
#   ' quelque bourrasque un',
#   '\n      \xa0peu violente.\xa0 \n  ',
#   '\n',
#   '\n',
#   'et prtant Me Bovary mère semblait prévenue',
#   '\n      contre sa bru elle',
#   '\n      lui trouvait',
#   '\n      \xa0',
#   'un genre trop relevé',
#   '\n',
#   ' \xa0pr leur position de fortune',
#   '\n      \xa0le bois & le sucre et',
#   '\n      \xa0la chandelle ',
#   'filaient',
#   '\n      comme dans une',
#   '\n      grande maison',
#   ' &',
#   '\n      la quantité de braise',
#   '\n      qui se brûlait à',
#   '\n      la cuisine aurait',
#   '\n      suffi pr vingt-cinq',
#   '\n      \xa0plats',
#   '\n',
#   '\n       {{',
#   'si jadis elle avait été aveuglée sur le',
#   '\n      compte de la veuve Dubuc, en revanche',
#   ' elle semblait',
#   '\n',
#   'maintenant',
#   ' prévenue ',
#   'sans motif',
#   ' contre Mlle',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Mr son époux',
#   '\n      Rouault tandis que ',
#   'son mari',
#   ' la déclarait, au contraire',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'déclarait',
#   '\n',
#   '\xa0une personne charmante. ',
#   'il disait que son fils avait',
#   '\n',
#   'Leur',
#   '\n',
#   'son fils avait bien fait de la prendre',
#   '\n',
#   "bien fait de la prendre. S'il avait été dupé une première",
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'si son fils une première fois avait été dupé',
#   '\n',
#   'fois - à qui la faute\xa0? ',
#   'est-ce que',
#   " les femmes d'ailleurs",
#   '\n',
#   'ne',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'rien',
#   "\n      s'entendaient à ",
#   'quelque chose . on était bien malheureux',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'pouvaient',
#   "\n      d'en ",
#   'avoir',
#   ' une. ',
#   'les pays où les ',
#   'maris',
#   ' ',
#   ' ',
#   'pouvaient',
#   '\n      les tuer ',
#   'impunément,',
#   ' ',
#   'étaient les mieux gouvernés et enfin',
#   '\n',
#   'toujours',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   ' en finissant ',
#   " de n'avoir",
#   '\n',
#   ' ',
#   "d'habitude",
#   ' ',
#   '& il se lamentait ',
#   'en finissant sur ce',
#   '\n',
#   '\xa0',
#   "qu'il n'avait ",
#   ' ',
#   "pas profité de sa jeunesse pr s'amuser",
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'suffisamment',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'suffisamment',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0',
#   'suffisamment',
#   '}} \n  ',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\n',
#   '\n',
#   ' [Transcription de Françoise Robin] ',
#   '\n'],
#  ['\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   '\n',
#   ' ',
#   ' I, chap.7 : Madame Bovary mère à Tostes - définitif, vol.1, folio 87 ',
#   '\n',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n       87 \n  ',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0',
#   'avidement',
#   '\n',
#   'de sa journée',
#   ', il mangeait ',
#   'avec appétit',
#   ' le reste du miroton',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0',
#   'en souriant',
#   '\n',
#   'épluchait son fromage ',
#   '/ en souriant',
#   ' , croquait une pomme',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'puis',
#   '\n',
#   'vidait la caraffe, ',
#   'après',
#   ' ',
#   'quoi il',
#   " s'allait ",
#   'se',
#   ' mettre au lit, ',
#   'sentant',
#   "\n      [le cidre éventé qu'il avait bu]",
#   ', se couchait sur le dos et',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 [',
#   'illis.]',
#   '\n      ronflait.',
#   'comme un mort',
#   '*',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 [',
#   'illis.]',
#   '\n',
#   "\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0Comme il avait eu longtemps l'habitude du bonnet",
#   '\n      de coton, son foulard ',
#   'mal mis',
#   ' ne lui tenait pas aux oreilles',
#   '\n      aussi ses cheveux le matin étaient',
#   '-ils',
#   ' rabattus pêle-mêle',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'sali',
#   's* par le',
#   '\n      sur sa figure, et ',
#   'plein du',
#   ' duvet de son oreiller, dont',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'blanchis',
#   '\n      les cordons ',
#   'de la coiffe',
#   ' se dénouaient pendant la nuit',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 toujours',
#   '\n      Il portait ',
#   'toujours',
#   ' de fortes bottes et qui avaient',
#   '\n      au coup de pied, deux plis épais obliquant vers les chevilles,',
#   "\n      tandis que le reste de l'empeigne ",
#   'dont rien ne ridait',
#   '\n      le cuir dur',
#   ', se continuait en ligne droite, tendu comme',
#   "\n      par un pied de bois. Il disait que «\xa0c'était bon assez bon",
#   '\n      pr la campagne.\xa0»',
#   "\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Sa mère l'approuvait ",
#   "d'ailleurs",
#   ' en cette',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   '\xa0voir',
#   "\n      économie. Car elle le venait, comme autrefois, lorsqu'il",
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 chez elle',
#   '\n      y avait eu ',
#   'dans son ménage',
#   ' quelque bourrasque un',
#   '\n      \xa0peu violente.\xa0 \n  ',
#   '\n',
#   '\n',
#   'et prtant Me Bovary mère semblait prévenue',
#   '\n      contre sa bru elle',
#   '\n      lui trouvait',
#   '\n      \xa0',
#   'un genre trop relevé',
#   '\n',
#   ' \xa0pr leur position de fortune',
#   '\n      \xa0le bois & le sucre et',
#   '\n      \xa0la chandelle ',
#   'filaient',
#   '\n      comme dans une',
#   '\n      grande maison',
#   ' &',
#   '\n      la quantité de braise',
#   '\n      qui se brûlait à',
#   '\n      la cuisine aurait',
#   '\n      suffi pr vingt-cinq',
#   '\n      \xa0plats',
#   '\n',
#   '\n       {{',
#   'si jadis elle avait été aveuglée sur le',
#   '\n      compte de la veuve Dubuc, en revanche',
#   ' elle semblait',
#   '\n',
#   'maintenant',
#   ' prévenue ',
#   'sans motif',
#   ' contre Mlle',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Mr son époux',
#   '\n      Rouault tandis que ',
#   'son mari',
#   ' la déclarait, au contraire',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'déclarait',
#   '\n',
#   '\xa0une personne charmante. ',
#   'il disait que son fils avait',
#   '\n',
#   'Leur',
#   '\n',
#   'son fils avait bien fait de la prendre',
#   '\n',
#   "bien fait de la prendre. S'il avait été dupé une première",
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'si son fils une première fois avait été dupé',
#   '\n',
#   'fois - à qui la faute\xa0? ',
#   'est-ce que',
#   " les femmes d'ailleurs",
#   '\n',
#   'ne',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'rien',
#   "\n      s'entendaient à ",
#   'quelque chose . on était bien malheureux',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'pouvaient',
#   "\n      d'en ",
#   'avoir',
#   ' une. ',
#   'les pays où les ',
#   'maris',
#   ' ',
#   ' ',
#   'pouvaient',
#   '\n      les tuer ',
#   'impunément,',
#   ' ',
#   'étaient les mieux gouvernés et enfin',
#   '\n',
#   'toujours',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   ' en finissant ',
#   " de n'avoir",
#   '\n',
#   ' ',
#   "d'habitude",
#   ' ',
#   '& il se lamentait ',
#   'en finissant sur ce',
#   '\n',
#   '\xa0',
#   "qu'il n'avait ",
#   ' ',
#   "pas profité de sa jeunesse pr s'amuser",
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'suffisamment',
#   '\n      \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ',
#   'suffisamment',
#   '\n',
#   '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0',
#   'suffisamment',
#   '}} \n  ',
#   '\n',
#   '\n       \xa0 \n  ',
#   '\n',
#   '\n',
#   '\n',
#   ' [Transcription de Françoise Robin] ',
#   '\n']]

# %%
from nltk.tokenize import word_tokenize

folios_tokenized = []

for text in folios_text:
    tokens = word_tokenize(text)
    folios_tokenized.append(tokens)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-8971a74b8daf> in <module>
#       4
#       5 for text in folios_text:
# ----> 6     tokens = word_tokenize(text)
#       7     folios_tokenized.append(tokens)
#
# /anaconda3/lib/python3.7/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     141     :type preserve_line: bool
#     142     """
# --> 143     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     144     return [
#     145         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /anaconda3/lib/python3.7/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     103     """
#     104     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# --> 105     return tokenizer.tokenize(text)
#     106
#     107
#
# /anaconda3/lib/python3.7/site-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1267         Given a text, returns a list of the sentences in that text.
#    1268         """
# -> 1269         return list(self.sentences_from_text(text, realign_boundaries))
#    1270
#    1271     def debug_decisions(self, text):
#
# /anaconda3/lib/python3.7/site-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1321         follows the period.
#    1322         """
# -> 1323         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1324
#    1325     def _slices_from_text(self, text):
#
# /anaconda3/lib/python3.7/site-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1321         follows the period.
#    1322         """
# -> 1323         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1324
#    1325     def _slices_from_text(self, text):
#
# /anaconda3/lib/python3.7/site-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1311         if realign_boundaries:
#    1312             slices = self._realign_boundaries(text, slices)
# -> 1313         for sl in slices:
#    1314             yield (sl.start, sl.stop)
#    1315
#
# /anaconda3/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1352         """
#    1353         realign = 0
# -> 1354         for sl1, sl2 in _pair_iter(slices):
#    1355             sl1 = slice(sl1.start + realign, sl1.stop)
#    1356             if not sl2:
#
# /anaconda3/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _pair_iter(it)
#     315     """
#     316     it = iter(it)
# --> 317     prev = next(it)
#     318     for el in it:
#     319         yield (prev, el)
#
# /anaconda3/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1325     def _slices_from_text(self, text):
#    1326         last_break = 0
# -> 1327         for match in self._lang_vars.period_context_re().finditer(text):
#    1328             context = match.group() + match.group('after_tok')
#    1329             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object
